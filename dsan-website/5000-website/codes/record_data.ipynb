# %% [raw]
# ---
# title:  "Data Gathering - Record Data"
# author: "Sheeba Moghal"
# format:
#     html:
#         embed-resources: true
#         code-fold: true
# execute:
#     echo: true
# jupyter: python3
# ---

# %% [markdown]
# # Record Data

# %% [markdown]
# The record data which is the gist or the main skeleton of my project focuses on understanding individual data points of all entire data. It has been retrieved using almost 152 columns in hand which are important for the EDA. The EDA for my project is a never-ending process and will become better at time. Since for my regression, I’m predicting GDP, having a holistic understanding of current and constant sources of data is just as important. The way economic data is wired is completely different to how the other data works, which is why, it has to be worked with caution.
#
# Another aspect I'd like to discuss is the autocorrelation and the seasonality of the dataset, since economic data does depend on the progression of time, essentially working on 5 datasets stacked on top of each other and dropping the year column does not make sense, however, I still do that since I'm not yet equipped with the skills to handle time-series data in a way the dataset consists of all the BRICS nations data in addition to their time. Hence, for the sake of this project, the data has to been seen with an assumption of time being constant, but in reality it isn't.

# %% [markdown]
# ## Data Source

# %% [markdown]
# The World Bank Data Bank is a comprehensive library that collects global data on economic, social, and environmental factors. This vast database is critical in gathering data from all nations and across many indicators, providing us with consistency in data collection. This can be a problem, especially if you're collecting data for five countries and the indicators or years of data collected aren't the same. This is made possible by offering a centralised platform for dependable data.

# %%
import pandas as pd
from IPython.display import display
brazil=pd.read_excel('../data/excel_files/brazil.xlsx')
china=pd.read_excel('../data/excel_files/china.xlsx')
southafrica=pd.read_excel('../data/excel_files/southafrica.xlsx')
india=pd.read_excel('../data/excel_files/india.xlsx')
russia=pd.read_excel('../data/excel_files/russia.xlsx')

# %% [markdown]
# The data for Brazil:

# %%
display(brazil.head(5))
# Out:
#                                          Series Name           Series Code  \
# 0     Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 1   Adjusted net national income (constant 2015 US$)        NY.ADJ.NNTY.KD
# 2  Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 3  Adjusted savings: consumption of fixed capital...     NY.ADJ.DKAP.GN.ZS
# 4  Adjusted savings: education expenditure (% of ...     NY.ADJ.AEDU.GN.ZS
#
#   Country Name Country Code        1973 [YR1973]        1974 [YR1974]  \
# 0       Brazil          BRA            13.768581             6.001818
# 1       Brazil          BRA  467846269164.406311  495925550202.552917
# 2       Brazil          BRA            11.055141             3.505249
# 3       Brazil          BRA            10.011622            10.094172
# 4       Brazil          BRA                    3             3.599282
#
#          1975 [YR1975]        1976 [YR1976]        1977 [YR1977]  \
# ...

# %% [markdown]
# Data for Russia:

# %%
display(russia.head(5))
# Out:
#                                          Series Name           Series Code  \
# 0     Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 1   Adjusted net national income (constant 2015 US$)        NY.ADJ.NNTY.KD
# 2  Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 3  Adjusted savings: consumption of fixed capital...     NY.ADJ.DKAP.GN.ZS
# 4  Adjusted savings: education expenditure (% of ...     NY.ADJ.AEDU.GN.ZS
#
#          Country Name Country Code        1994 [YR1994]        1995 [YR1995]  \
# 0  Russian Federation          RUS           -20.796923            -9.137814
# 1  Russian Federation          RUS  361146926879.664185  328145992820.509216
# 2  Russian Federation          RUS           -20.769775             -9.11814
# 3  Russian Federation          RUS            47.004948            48.011109
# 4  Russian Federation          RUS                  3.9                  3.9
#
# ...

# %% [markdown]
# Data for India:

# %%
display(india.head(5))
# Out:
#                                          Series Name        Series Code  \
# 0     Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 1   Adjusted net national income (constant 2015 US$)     NY.ADJ.NNTY.KD
# 2  Adjusted savings: consumption of fixed capital...  NY.ADJ.DKAP.GN.ZS
# 3  Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
# 4  Adjusted savings: net national savings (% of GNI)  NY.ADJ.NNAT.GN.ZS
#
#   Country Name Country Code  1979 [YR1979]  1980 [YR1980]  1981 [YR1981]  \
# 0        India          IND  -4.294464e+00   1.197854e+01  -2.572689e+00
# 1        India          IND   2.211879e+11   2.476830e+11   2.413109e+11
# 2        India          IND   8.340217e+00   8.055168e+00   8.393346e+00
# 3        India          IND   2.600000e+00   2.600000e+00   2.600000e+00
# 4        India          IND   7.427910e+00   6.418183e+00   7.373027e+00
#
#    1982 [YR1982]  1983 [YR1983]  1984 [YR1984]  ...  2013 [YR2013]  \
# ...

# %% [markdown]
# Data for China:

# %%
display(china.head(5))
# Out:
#                                          Series Name        Series Code  \
# 0     Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 1   Adjusted net national income (constant 2015 US$)     NY.ADJ.NNTY.KD
# 2  Adjusted savings: consumption of fixed capital...  NY.ADJ.DKAP.GN.ZS
# 3  Adjusted savings: consumption of fixed capital...     NY.ADJ.DKAP.CD
# 4  Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
#
#   Country Name Country Code       1989 [YR1989]       1990 [YR1990]  \
# 0        China          CHN                  ..                  ..
# 1        China          CHN                  ..                  ..
# 2        China          CHN            9.410207            9.758755
# 3        China          CHN  32747520363.167801  35326694769.442497
# 4        China          CHN                 1.6             1.78618
#
#         1991 [YR1991]       1992 [YR1992]       1993 [YR1993]  \
# ...

# %% [markdown]
# Data for South Africa

# %%
display(southafrica.head(5))
# Out:
#                                          Series Name           Series Code  \
# 0     Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 1   Adjusted net national income (constant 2015 US$)        NY.ADJ.NNTY.KD
# 2  Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 3  Adjusted savings: consumption of fixed capital...     NY.ADJ.DKAP.GN.ZS
# 4  Adjusted savings: education expenditure (% of ...     NY.ADJ.AEDU.GN.ZS
#
#    Country Name Country Code       1973 [YR1973]       1974 [YR1974]  \
# 0  South Africa          ZAF           13.995649            6.064966
# 1  South Africa          ZAF  83566486105.631912  88634764781.144974
# 2  South Africa          ZAF           10.797713            3.127517
# 3  South Africa          ZAF           12.087193           12.005429
# 4  South Africa          ZAF            5.039765            5.039765
#
#         1975 [YR1975]       1976 [YR1976]       1977 [YR1977]  \
# ...

# %% [markdown]
# There is a lot of cleaning to do which shall be explored in the later sections of the website.

# %% [markdown]
# # Sources

# %% [markdown]
# 1. World Bank. (n.d.). DataBank. Retrieved from https://databank.worldbank.org/
